# %% [markdown]
# # Cardio Good Fitness Case Study - Descriptive Statistics
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness. The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics. The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months. The data are stored in the CardioGoodFitness.csv file.
#
# ### The team identifies the following customer variables to study:
#   - product purchased, TM195, TM498, or TM798;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the treadmill each week;
#   - average number of miles the customer expects to walk/run each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#
# ### Perform descriptive analytics to create a customer profile for each CardioGood Fitness treadmill product line.

# %%
# Load the necessary packages

import numpy as np
import pandas as pd

# %%
# Load the Cardio Dataset

mydata = pd.read_csv('C:\\Users\\Ajitha.Rajkumar\\OneDrive - Reliance Corporate IT Park Limited\\Desktop\\Python\\BA End term\\GL\\CardioGoodFitness.csv')

# %%
mydata.head()
# Out:
#   Product  Age  Gender MaritalStatus  Income  Usage  Fitness  Education  \
# 0   TM195   23    Male     Partnered   38658      3        1         16
# 1   TM195   22  Female     Partnered   35247      3        2         14
# 2   TM195   23  Female     Partnered   34110      2        2         15
# 3   TM195   25  Female     Partnered   53439      2        2         14
# 4   TM195   25  Female     Partnered   40932      2        2         16
#
#    Usage.1  Miles  ...  Single Unnamed: 19  Income.1  Miles.1  Unnamed: 22  \
# 0        3     47  ...    94.0         NaN     38658       47          NaN
# 1        3     66  ...    94.0         NaN     35247       66          NaN
# 2        2     38  ...    75.0         NaN     34110       38          NaN
# 3        2     47  ...   113.0         NaN     53439       47          NaN
# 4        2     47  ...    66.0         NaN     40932       47          NaN
#
#    Fitness1  Fitness2  Fitness3  Fitness4  Fitness5
# 0      47.0      66.0      66.0     113.0     188.0
# 1       NaN      47.0      75.0     132.0     180.0
# 2       NaN      47.0      85.0     141.0     280.0
# 3       NaN      66.0      75.0     132.0     200.0
# 4       NaN      38.0      85.0     106.0      80.0
#
# [5 rows x 28 columns]

# %%
mydata.describe(include="all")
# Out:
#        Product         Age Gender MaritalStatus         Income       Usage  \
# count      180  180.000000    180           180     180.000000  180.000000
# unique       3         NaN      2             2            NaN         NaN
# top      TM195         NaN   Male     Partnered            NaN         NaN
# freq        80         NaN    104           107            NaN         NaN
# mean       NaN   28.788889    NaN           NaN   53719.577778    3.455556
# std        NaN    6.943498    NaN           NaN   16506.684226    1.084797
# min        NaN   18.000000    NaN           NaN   29562.000000    2.000000
# 25%        NaN   24.000000    NaN           NaN   44058.750000    3.000000
# 50%        NaN   26.000000    NaN           NaN   50596.500000    3.000000
# 75%        NaN   33.000000    NaN           NaN   58668.000000    4.000000
# max        NaN   50.000000    NaN           NaN  104581.000000    7.000000
#
#            Fitness   Education     Usage.1       Miles  ...      Single  \
# count   180.000000  180.000000  180.000000  180.000000  ...   73.000000
# unique         NaN         NaN         NaN         NaN  ...         NaN
# top            NaN         NaN         NaN         NaN  ...         NaN
# freq           NaN         NaN         NaN         NaN  ...         NaN
# mean      3.311111   15.572222    3.455556  103.194444  ...  101.589041
# std       0.958869    1.617055    1.084797   51.863605  ...   38.959678
# min       1.000000   12.000000    2.000000   21.000000  ...   21.000000
# 25%       3.000000   14.000000    3.000000   66.000000  ...   75.000000
# 50%       3.000000   16.000000    3.000000   94.000000  ...   95.000000
# 75%       4.000000   16.000000    4.000000  114.750000  ...  113.000000
# max       5.000000   21.000000    7.000000  360.000000  ...  200.000000
#
#        Unnamed: 19       Income.1     Miles.1  Unnamed: 22   Fitness1  \
# count          0.0     180.000000  180.000000          0.0   2.000000
# unique         NaN            NaN         NaN          NaN        NaN
# top            NaN            NaN         NaN          NaN        NaN
# freq           NaN            NaN         NaN          NaN        NaN
# mean           NaN   53719.577778  103.194444          NaN  34.000000
# std            NaN   16506.684226   51.863605          NaN  18.384776
# min            NaN   29562.000000   21.000000          NaN  21.000000
# 25%            NaN   44058.750000   66.000000          NaN  27.500000
# 50%            NaN   50596.500000   94.000000          NaN  34.000000
# 75%            NaN   58668.000000  114.750000          NaN  40.500000
# max            NaN  104581.000000  360.000000          NaN  47.000000
#
#          Fitness2    Fitness3    Fitness4    Fitness5
# count   26.000000   97.000000   24.000000   31.000000
# unique        NaN         NaN         NaN         NaN
# top           NaN         NaN         NaN         NaN
# freq          NaN         NaN         NaN         NaN
# mean    51.692308   87.185567  131.625000  178.935484
# std     11.824616   19.203586   37.623781   60.290926
# min     38.000000   53.000000   74.000000   80.000000
# 25%     43.250000   75.000000  106.000000  150.000000
# 50%     47.000000   85.000000  127.000000  170.000000
# 75%     53.000000   95.000000  160.000000  200.000000
# max     85.000000  170.000000  212.000000  360.000000
#
# [11 rows x 28 columns]

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   MaritalStatus  180 non-null    object
#  4   Income         180 non-null    int64
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Education      180 non-null    int64
#  8   Usage.1        180 non-null    int64
#  9   Miles          180 non-null    int64
#  10  TM195          80 non-null     float64
#  11  TM498          63 non-null     object
#  12  TM798          40 non-null     float64
#  13  Unnamed: 13    0 non-null      float64
#  14  Female         76 non-null     float64
#  15  Male           104 non-null    float64
#  16  Unnamed: 16    0 non-null      float64
#  17  Partnered      107 non-null    float64
#  18  Single         73 non-null     float64
#  19  Unnamed: 19    0 non-null      float64
#  20  Income.1       180 non-null    int64
#  21  Miles.1        180 non-null    int64
#  22  Unnamed: 22    0 non-null      float64
#  23  Fitness1       2 non-null      float64
#  24  Fitness2       26 non-null     float64
#  25  Fitness3       97 non-null     float64
#  26  Fitness4       24 non-null     float64
#  27  Fitness5       31 non-null     float64
# dtypes: float64(15), int64(9), object(4)
# memory usage: 39.5+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage.1'}>,
#         <Axes: title={'center': 'Miles'}>,
#         <Axes: title={'center': 'TM195'}>,
#         <Axes: title={'center': 'TM798'}>,
#         <Axes: title={'center': 'Unnamed: 13'}>],
#        [<Axes: title={'center': 'Female'}>,
#         <Axes: title={'center': 'Male'}>,
#         <Axes: title={'center': 'Unnamed: 16'}>,
#         <Axes: title={'center': 'Partnered'}>,
#         <Axes: title={'center': 'Single'}>],
#        [<Axes: title={'center': 'Unnamed: 19'}>,
#         <Axes: title={'center': 'Income.1'}>,
#         <Axes: title={'center': 'Miles.1'}>,
#         <Axes: title={'center': 'Unnamed: 22'}>,
#         <Axes: title={'center': 'Fitness1'}>],
#        [<Axes: title={'center': 'Fitness2'}>,
#         <Axes: title={'center': 'Fitness3'}>,
#         <Axes: title={'center': 'Fitness4'}>,
#         <Axes: title={'center': 'Fitness5'}>, <Axes: >]], dtype=object)

# %%
import seaborn as sns

sns.boxplot(x="Gender", y="Age", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(mydata['Product'],mydata['Gender'] )
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(mydata['Product'],mydata['MaritalStatus'] )
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
sns.countplot(x="Product", hue="Gender", data=mydata)

# %%
pd.pivot_table(mydata, index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'], aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
#         Male       10        21     10        21     10
# TM798   Female      3         4      3         4      3
#         Male       14        19     14        19     14

# %%
pd.pivot_table(mydata,'Income', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
pd.pivot_table(mydata,'Miles', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
sns.pairplot(mydata)

# %%
mydata['Age'].std()
# Out:
# 6.9434981353997953

# %%
mydata['Age'].mean()
# Out:
# 28.788888888888888

# %%
sns.distplot(mydata['Age'])

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bade860>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc68518>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Income')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bba48d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b9cedd8>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Miles')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1a5c3cc0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a19e4b828>], dtype=object)

# %%
mydata.hist(by='Product',column = 'Miles', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bfdd668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c04e1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1c1271d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c15e710>]], dtype=object)

# %%
corr = mydata.corr()
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(corr, annot=True)

# %%
# Simple Linear Regression


#Load function from sklearn
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

y = mydata['Miles']
x = mydata[['Usage','Fitness']]

# Train the model using the training sets
regr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regr.coef_
# Out:
# array([ 20.21486334,  27.20649954])

# %%
regr.intercept_
# Out:
# -56.742881784648617

# %%
# MilesPredicted = -56.74 + 20.21*Usage + 27.20*Fitness
